# %%
# Optional clean up
# !docker stop positron_host -t 1
# !docker container rm positron_host
# !docker image rm jakub-deka/positron:latest

# !docker build -t jakub-deka/positron .

# !docker run -t -d -i --name positron_host jakub-deka/positron
# !docker start positron_host
# Out:
# Error response from daemon: No such container: positron_host
# Error response from daemon: No such container: positron_host
# Error response from daemon: No such image: jakub-deka/positron:latest
# #0 building with "desktop-linux" instance using docker driver
#
# #1 [internal] load build definition from Dockerfile
# #1 transferring dockerfile: 213B done
# #1 DONE 0.1s
#
# #2 [internal] load metadata for docker.io/library/debian:latest
# #2 DONE 1.7s
#
# #3 [internal] load .dockerignore
# #3 transferring context: 2B done
# #3 DONE 0.1s
#
# #4 [1/4] FROM docker.io/library/debian:latest@sha256:10901ccd8d249047f9761845b4594f121edef079cfd8224edebd9ea726f0a7f6
# #4 resolve docker.io/library/debian:latest@sha256:10901ccd8d249047f9761845b4594f121edef079cfd8224edebd9ea726f0a7f6 0.0s done
# #4 DONE 0.0s
#
# #4 [1/4] FROM docker.io/library/debian:latest@sha256:10901ccd8d249047f9761845b4594f121edef079cfd8224edebd9ea726f0a7f6
# ...
